# %%
import pyttsx3
# engine = pyttsx3.init()
# engine.say("救命呀")
# engine.runAndWait()

voices = engine.getProperty('voices')
for voice in voices:
    print ('id = {}\tname = {} \n'.format(voice.id, voice.name))

engine.setProperty('voice', 'Mandarin') 

 
# 改变语速  范围为0-200   默认值为200
rate = engine.getProperty('rate') 
engine.setProperty('rate', rate-40)
 
# 设置音量  范围为0.0-1.0  默认值为1.0
engine.setProperty('volume', 0.7)
 
# 预设要朗读的文本数据
line = "你好，世界！" #要播报的内容
engine.say(line)
engine.runAndWait()
# Out:
# id = afrikaans	name = afrikaans
#
# id = aragonese	name = aragonese
#
# id = bulgarian	name = bulgarian
#
# id = bengali	name = bengali
#
# id = bosnian	name = bosnian
#
# id = catalan	name = catalan
#
# id = czech	name = czech
#
# id = welsh	name = welsh
#
# id = danish	name = danish
#
# id = german	name = german
#
# id = greek	name = greek
#
# id = default	name = default
#
# id = english	name = english
#
# id = en-scottish	name = en-scottish
#
# id = english-north	name = english-north
#
# id = english_rp	name = english_rp
#
# id = english_wmids	name = english_wmids
#
# id = english-us	name = english-us
#
# id = en-westindies	name = en-westindies
#
# id = esperanto	name = esperanto
#
# id = spanish	name = spanish
#
# id = spanish-latin-am	name = spanish-latin-am
#
# id = estonian	name = estonian
#
# id = basque-test	name = basque-test
#
# id = Persian+English-UK	name = Persian+English-UK
#
# id = Persian+English-US	name = Persian+English-US
#
# id = persian-pinglish	name = persian-pinglish
#
# id = finnish	name = finnish
#
# id = french-Belgium	name = french-Belgium
#
# id = french	name = french
#
# id = irish-gaeilge	name = irish-gaeilge
#
# id = greek-ancient	name = greek-ancient
#
# id = gujarati-test	name = gujarati-test
#
# id = hindi	name = hindi
#
# id = croatian	name = croatian
#
# id = hungarian	name = hungarian
#
# id = armenian	name = armenian
#
# id = armenian-west	name = armenian-west
#
# id = interlingua	name = interlingua
#
# id = indonesian	name = indonesian
#
# id = icelandic	name = icelandic
#
# id = italian	name = italian
#
# id = lojban	name = lojban
#
# id = georgian	name = georgian
#
# id = kannada	name = kannada
#
# id = kurdish	name = kurdish
#
# id = latin	name = latin
#
# id = lingua_franca_nova	name = lingua_franca_nova
#
# id = lithuanian	name = lithuanian
#
# id = latvian	name = latvian
#
# id = macedonian	name = macedonian
#
# id = malayalam	name = malayalam
#
# id = malay	name = malay
#
# id = nepali	name = nepali
#
# id = dutch	name = dutch
#
# id = norwegian	name = norwegian
#
# id = punjabi	name = punjabi
#
# id = polish	name = polish
#
# id = brazil	name = brazil
#
# id = portugal	name = portugal
#
# id = romanian	name = romanian
#
# id = russian	name = russian
#
# id = slovak	name = slovak
#
# id = albanian	name = albanian
#
# id = serbian	name = serbian
#
# id = swedish	name = swedish
#
# id = swahili-test	name = swahili-test
#
# id = tamil	name = tamil
#
# id = telugu-test	name = telugu-test
#
# id = turkish	name = turkish
#
# id = vietnam	name = vietnam
#
# id = vietnam_hue	name = vietnam_hue
#
# id = vietnam_sgn	name = vietnam_sgn
#
# id = Mandarin	name = Mandarin
#
# id = cantonese	name = cantonese
